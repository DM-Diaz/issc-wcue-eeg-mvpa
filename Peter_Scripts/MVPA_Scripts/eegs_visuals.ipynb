# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
class EEG_Class:
    pass

# %%
eegs_E1 = np.load("eegs_E1.npy", allow_pickle=True)
eegs_E2_baseline = np.load("eegs_E2_baseline.npy", allow_pickle=True)
eegs_E2_penalty = np.load("eegs_E2_penalty.npy", allow_pickle=True)

# %%
plt.plot([eeg.low_data.shape[0] for eeg in eegs_E1], label="low")
plt.plot([eeg.high_data.shape[0] for eeg in eegs_E1], label="high")

plt.title("E1")
plt.legend()

plt.xlabel("Subject")
plt.ylabel("Count")

plt.plot()
# Out:
# []

# %%
plt.plot([eeg.low_data.shape[0] for eeg in eegs_E2_baseline], label="low_baseline")
plt.plot([eeg.high_data.shape[0] for eeg in eegs_E2_baseline], label="high_baseline")
plt.plot([eeg.low_data.shape[0] for eeg in eegs_E2_penalty], label="low_penalty")
plt.plot([eeg.high_data.shape[0] for eeg in eegs_E2_penalty], label="high_penalty")

plt.title("E2")
plt.legend()

plt.xlabel("Subject")
plt.ylabel("Count")

# plt.savefig('my_plot.eps', format='eps')
# plt.savefig('my_plot')

plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
